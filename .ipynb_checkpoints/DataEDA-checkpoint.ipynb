# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Cleaned_Data.csv')
data.head()
# Out:
#                    Job Title                 Salary Estimate  \
# 0  DATA SCIENTIST-HEALTHCARE    $56K - $96K (Glassdoor est.)
# 1   Principal Data Scientist  $139K - $214K (Glassdoor est.)
# 2           Senior Scientist    $68K - $97K (Glassdoor est.)
# 3       Staff Data Scientist  $114K - $144K (Glassdoor est.)
# 4             Data Scientist  $120K - $121K (Glassdoor est.)
#
#                                      Job Description  Rating    Company Name  \
# 0  The Data Scientist has a deep understanding of...     3.7  Premier Health
# 1  Working out of our Chevy Chase, MD/Washington ...     3.5           GEICO
# 2  Position Summary:\nThe Senior Scientist is a m...     3.5     LGC Limited
# 3  Alteryx is searching for a Staff Data Scientis...     3.5   Alteryx, Inc.
# 4  Who Are We?\nQinetiQ Inc. is a leading innovat...     2.5    QinetiQ Inc.
#
#           Location  Per Hour  Employee Provided  Min Salary  Max Salary  \
# 0       Dayton, OH         0                  0          56          56
# 1  Chevy Chase, MD         0                  0         139         139
# 2   Alexandria, MN         0                  0          68          68
# 3       Boston, MA         0                  0         114         114
# 4       Lorton, VA         0                  0         120         120
#
#    Average Salary  Python  R_studio  Spark  Excel  AWS  SQL
# 0            56.0       0         1      0      0    0    0
# 1           139.0       0         1      0      0    0    0
# 2            68.0       0         1      0      0    0    0
# 3           114.0       0         1      0      0    0    0
# 4           120.0       0         1      0      0    0    0

# %%
data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Per Hour', 'Employee Provided',
#        'Min Salary', 'Max Salary', 'Average Salary', 'Python', 'R_studio',
#        'Spark', 'Excel', 'AWS', 'SQL'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower() or 'scientist' in title.lower():
        return 'Data Scientist'
    elif 'data engineer' in title.lower():
        return 'Data Engineer'
    elif 'analyst' in title.lower():
        return 'Analyst'
    elif 'machine learning' in title.lower():
        return 'Machine Learning'
    elif 'director' in title.lower():
        return 'Director'
    elif 'manager' in title.lower():
        return 'Manager'
    else:
        return 'n/a'

# %%
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'principal' in title.lower() or 'lead' in title.lower():
        return 'Senior'
    elif 'jr' in title.lower() or 'junior' in title.lower():
        return 'Junior'
    else:
        return 'n/a'

# %%
data['Title'] = data['Job Title'].apply(title_simplifier)
data['Seniority'] = data['Job Title'].apply(seniority)
data['Seniority'].value_counts()
# Out:
# n/a       18
# Senior     4
# Name: Seniority, dtype: int64

# %%
data['desc_len'] = data['Job Description'].apply(lambda x: len(x))
data['min_salary'] = data['Min Salary']
data['max_salary'] = data['Max Salary']

data['hourly'] = data['Per Hour']

# %%
data['min_salary'] = data.apply(lambda x: x.min_salary*2 if x.hourly == 1 else x.min_salary, axis=1)
data['max_salary'] = data.apply(lambda x: x.max_salary*2 if x.hourly == 1 else x.max_salary, axis=1)

# %%
data[data.hourly==1][['hourly', 'min_salary', 'max_salary']]
# Out:
#     hourly  min_salary  max_salary
# 9        1          48          48
# 18       1          34          34

# %%
data.describe()
# Out:
#           Rating   Per Hour  Employee Provided  Min Salary  Max Salary  \
# count  22.000000  22.000000               22.0   22.000000   22.000000
# mean    3.368182   0.090909                0.0   68.045455   68.045455
# std     1.142006   0.294245                0.0   30.973840   30.973840
# min    -1.000000   0.000000                0.0   17.000000   17.000000
# 25%     3.425000   0.000000                0.0   45.750000   45.750000
# 50%     3.500000   0.000000                0.0   64.500000   64.500000
# 75%     3.800000   0.000000                0.0   80.500000   80.500000
# max     4.700000   1.000000                0.0  139.000000  139.000000
#
#        Average Salary     Python  R_studio  Spark      Excel   AWS        SQL  \
# count       22.000000  22.000000      22.0   22.0  22.000000  22.0  22.000000
# mean        68.045455   0.045455       1.0    0.0   0.136364   0.0   0.045455
# std         30.973840   0.213201       0.0    0.0   0.351250   0.0   0.213201
# min         17.000000   0.000000       1.0    0.0   0.000000   0.0   0.000000
# 25%         45.750000   0.000000       1.0    0.0   0.000000   0.0   0.000000
# 50%         64.500000   0.000000       1.0    0.0   0.000000   0.0   0.000000
# 75%         80.500000   0.000000       1.0    0.0   0.000000   0.0   0.000000
# max        139.000000   1.000000       1.0    0.0   1.000000   0.0   1.000000
#
#           desc_len  min_salary  max_salary     hourly
# count    22.000000   22.000000   22.000000  22.000000
# mean   1109.545455   69.909091   69.909091   0.090909
# std     770.379605   28.523856   28.523856   0.294245
# min       2.000000   34.000000   34.000000   0.000000
# 25%     728.250000   48.750000   48.750000   0.000000
# 50%     941.000000   64.500000   64.500000   0.000000
# 75%    1224.500000   80.500000   80.500000   0.000000
# max    3503.000000  139.000000  139.000000   1.000000

# %%
data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Per Hour', 'Employee Provided',
#        'Min Salary', 'Max Salary', 'Average Salary', 'Python', 'R_studio',
#        'Spark', 'Excel', 'AWS', 'SQL', 'Title', 'Seniority', 'desc_len',
#        'min_salary', 'max_salary', 'hourly'],
#       dtype='object')

# %%
data['Rating'].hist()
# Out:
# <AxesSubplot:>

# %%
# data['avg_salary'].hist()
data['avg_salary'] = data['Average Salary']
data['avg_salary'].hist()
# Out:
# <AxesSubplot:>

# %%
data['desc_len'].hist()
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=['avg_salary','Rating'])
# Out:
# <AxesSubplot:>

# %%
data[['avg_salary','Rating','min_salary','max_salary']].corr()
# Out:
#             avg_salary    Rating  min_salary  max_salary
# avg_salary    1.000000  0.082970    0.982145    0.982145
# Rating        0.082970  1.000000    0.071245    0.071245
# min_salary    0.982145  0.071245    1.000000    1.000000
# max_salary    0.982145  0.071245    1.000000    1.000000

# %%
data.head(1)
# Out:
#                    Job Title               Salary Estimate  \
# 0  DATA SCIENTIST-HEALTHCARE  $56K - $96K (Glassdoor est.)
#
#                                      Job Description  Rating    Company Name  \
# 0  The Data Scientist has a deep understanding of...     3.7  Premier Health
#
#      Location  Per Hour  Employee Provided  Min Salary  Max Salary  ...  \
# 0  Dayton, OH         0                  0          56          56  ...
#
#    Excel  AWS  SQL           Title  Seniority  desc_len  min_salary  \
# 0      0    0    0  Data Scientist        n/a       438          56
#
#   max_salary hourly  avg_salary
# 0         56      0        56.0
#
# [1 rows x 24 columns]

# %%
data = data[['Title','Rating','Job Description', 'Company Name','Location','Employee Provided','Python','Excel','AWS','SQL','Seniority','desc_len','min_salary','max_salary','avg_salary','hourly']]
data
# Out:
#              Title  Rating                                    Job Description  \
# 0   Data Scientist     3.7  The Data Scientist has a deep understanding of...
# 1   Data Scientist     3.5  Working out of our Chevy Chase, MD/Washington ...
# 2   Data Scientist     3.5  Position Summary:\nThe Senior Scientist is a m...
# 3   Data Scientist     3.5  Alteryx is searching for a Staff Data Scientis...
# 4   Data Scientist     2.5  Who Are We?\nQinetiQ Inc. is a leading innovat...
# 5   Data Scientist     3.4  Classification:\nSalary\nJob Description:\nAre...
# 6   Data Scientist     3.1  The Research department is seeking a qualified...
# 7   Data Scientist     3.5  LGC, Biosearch Technologies is seeking a detai...
# 8   Data Scientist     3.5  LGC, Biosearch Technologies is looking for a h...
# 9   Data Scientist     3.8  White Plains Hospital Job Description\nTitle: ...
# 10   Data Engineer     3.8  Schedule: Mon- Fri Overview:\nThe data enginee...
# 11  Data Scientist     4.7  Are you passionate about using data visualizat...
# 12  Data Scientist     3.5  Position Overview:\nCatalent hires people with...
# 13             n/a    -1.0                                                 -1
# 14  Data Scientist     3.6  Sanvita Medical, an exciting new medical devic...
# 15   Data Engineer     4.5  Overview:\nDo you enjoy working with other peo...
# 16  Data Scientist     3.8  BioFire Diagnostics, LLC. is seeking a bright ...
# 17  Data Scientist     3.8  BioFire Diagnostics (BFDX), LLC. is looking fo...
# 18  Data Scientist     2.0  MedLogic Laboratory\nMolecular Technologist\nL...
# 19   Data Engineer     3.3  The NFI Data and Analytics group is looking fo...
# 20             n/a     4.6  WHO WE LOOK FOR\n\nAn SEI Consultant is a mast...
# 21  Data Scientist     3.5  Position Overview:\nCatalent hires people with...
#
#                                       Company Name            Location  \
# 0                                   Premier Health          Dayton, OH
# 1                                            GEICO     Chevy Chase, MD
# 2                                      LGC Limited      Alexandria, MN
# 3                                    Alteryx, Inc.          Boston, MA
# 4                                     QinetiQ Inc.          Lorton, VA
# 5                          Laticrete International         Bethany, CT
# 6                                    INFICON, Inc.   East Syracuse, NY
# 7                                      LGC Limited       Middleton, WI
# 8                                      LGC Limited       Middleton, WI
# 9                            White Plains Hospital    White Plains, NY
# 10                      America First Credit Union           Ogden, UT
# 11  Johns Hopkins Applied Physics Laboratory (APL)          Laurel, MD
# 12                       Catalent Pharma Solutions      Winchester, KY
# 13                                              -1                  -1
# 14                                 Nova Biomedical       Billerica, MA
# 15                      Idaho Central Credit Union        Chubbuck, ID
# 16                       BioFire Diagnostics, LLC.  Salt Lake City, UT
# 17                       BioFire Diagnostics, LLC.  Salt Lake City, UT
# 18                           MedLogic Laboratories     Baton Rouge, LA
# 19                                  NFI Industries          Camden, NJ
# 20                                             SEI      Cincinnati, OH
# 21                       Catalent Pharma Solutions      Winchester, KY
#
#     Employee Provided  Python  Excel  AWS  SQL Seniority  desc_len  \
# 0                   0       0      0    0    0       n/a       438
# 1                   0       0      0    0    0    Senior       972
# 2                   0       0      0    0    0    Senior       975
# 3                   0       0      0    0    0       n/a      1243
# 4                   0       0      0    0    0       n/a      1084
# 5                   0       0      0    0    0    Senior       549
# 6                   0       0      0    0    0       n/a       944
# 7                   0       0      0    0    0       n/a       717
# 8                   0       0      0    0    0    Senior       938
# 9                   0       0      0    0    0       n/a       479
# 10                  0       0      0    0    0       n/a       898
# 11                  0       0      0    0    0       n/a      2386
# 12                  0       0      0    0    0       n/a      1440
# 13                  0       0      0    0    0       n/a         2
# 14                  0       0      0    0    0       n/a       762
# 15                  0       0      0    0    0       n/a       808
# 16                  0       0      0    0    0       n/a       842
# 17                  0       0      1    0    0       n/a      1169
# 18                  0       0      0    0    0       n/a       488
# 19                  0       1      1    0    1       n/a      3503
# 20                  0       0      1    0    0       n/a      2342
# 21                  0       0      0    0    0       n/a      1431
#
#     min_salary  max_salary  avg_salary  hourly
# 0           56          56        56.0       0
# 1          139         139       139.0       0
# 2           68          68        68.0       0
# 3          114         114       114.0       0
# 4          120         120       120.0       0
# 5           75          75        75.0       0
# 6           51          51        51.0       0
# 7           62          62        62.0       0
# 8           98          98        98.0       0
# 9           48          48        24.0       1
# 10          44          44        44.0       0
# 11          79          79        79.0       0
# 12          38          38        38.0       0
# 13          61          61        61.0       0
# 14          35          35        35.0       0
# 15          61          61        61.0       0
# 16          91          91        91.0       0
# 17          67          67        67.0       0
# 18          34          34        17.0       1
# 19          76          76        76.0       0
# 20          81          81        81.0       0
# 21          40          40        40.0       0

# %%
for i in data.columns:
    df = data[i].value_counts()
    sns.barplot(x=df.index, y=df)
    print('Graph for %s: = %d' %(i, len(df)))
    plt.show()
# Out:
# Graph for Title: = 3
# Graph for Rating: = 13
# Graph for Job Description: = 22
# Graph for Company Name: = 18
# Graph for Location: = 19
# Graph for Employee Provided: = 1
# Graph for Python: = 2
# Graph for Excel: = 2
# Graph for AWS: = 1
# Graph for SQL: = 2
# Graph for Seniority: = 2
# Graph for desc_len: = 22
# Graph for min_salary: = 21
# Graph for max_salary: = 21
# Graph for avg_salary: = 21
# Graph for hourly: = 2

# %%
for i in data.columns:
    df = data[i].value_counts()
    datax = sns.barplot(x=df.index, y=df)
    datax.set_xticklabels(datax.get_xticklabels(),rotation=40)
    print('Graph for %s: = %d' %(i, len(df)))
#     print(df)   
    plt.show()
# Out:
# Graph for Title: = 3
# Graph for Rating: = 13
# Graph for Job Description: = 22
# Graph for Company Name: = 18
# Graph for Location: = 19
# Graph for Employee Provided: = 1
# Graph for Python: = 2
# Graph for Excel: = 2
# Graph for AWS: = 1
# Graph for SQL: = 2
# Graph for Seniority: = 2
# Graph for desc_len: = 22
# Graph for min_salary: = 21
# Graph for max_salary: = 21
# Graph for avg_salary: = 21
# Graph for hourly: = 2

# %%
pd.pivot_table(data, index='Title', values='avg_salary')
# Out:
#                 avg_salary
# Title
# Data Engineer    60.333333
# Data Scientist   69.058824
# n/a              71.000000

# %%
pd.pivot_table(data, index=['Title','Rating'], values='avg_salary')
# Out:
#                        avg_salary
# Title          Rating
# Data Engineer   3.3     76.000000
#                 3.8     44.000000
#                 4.5     61.000000
# Data Scientist  2.0     17.000000
#                 2.5    120.000000
#                 3.1     51.000000
#                 3.4     75.000000
#                 3.5     79.857143
#                 3.6     35.000000
#                 3.7     56.000000
#                 3.8     60.666667
#                 4.7     79.000000
# n/a            -1.0     61.000000
#                 4.6     81.000000

# %%
pd.pivot_table(data, index=['Title','Seniority','Location'], values='avg_salary').sort_values('avg_salary', ascending=False)
# Out:
#                                              avg_salary
# Title          Seniority Location
# Data Scientist Senior    Chevy Chase, MD          139.0
#                n/a       Lorton, VA               120.0
#                          Boston, MA               114.0
#                Senior    Middleton, WI             98.0
# n/a            n/a       Cincinnati, OH            81.0
# Data Scientist n/a       Salt Lake City, UT        79.0
#                          Laurel, MD                79.0
# Data Engineer  n/a       Camden, NJ                76.0
# Data Scientist Senior    Bethany, CT               75.0
#                          Alexandria, MN            68.0
#                n/a       Middleton, WI             62.0
# Data Engineer  n/a       Chubbuck, ID              61.0
# n/a            n/a       -1                        61.0
# Data Scientist n/a       Dayton, OH                56.0
#                          East Syracuse, NY         51.0
# Data Engineer  n/a       Ogden, UT                 44.0
# Data Scientist n/a       Winchester, KY            39.0
#                          Billerica, MA             35.0
#                          White Plains, NY          24.0
#                          Baton Rouge, LA           17.0

# %%
pd.pivot_table(data, index=['Title','Seniority','Location'], values='avg_salary', aggfunc='count').sort_values('avg_salary', ascending=False)
# Out:
#                                              avg_salary
# Title          Seniority Location
# Data Scientist n/a       Winchester, KY               2
#                          Salt Lake City, UT           2
# Data Engineer  n/a       Camden, NJ                   1
#                          Chubbuck, ID                 1
# n/a            n/a       -1                           1
# Data Scientist n/a       White Plains, NY             1
#                          Middleton, WI                1
#                          Lorton, VA                   1
#                          Laurel, MD                   1
#                          East Syracuse, NY            1
#                          Dayton, OH                   1
#                          Boston, MA                   1
#                          Billerica, MA                1
#                          Baton Rouge, LA              1
#                Senior    Middleton, WI                1
#                          Chevy Chase, MD              1
#                          Bethany, CT                  1
#                          Alexandria, MN               1
# Data Engineer  n/a       Ogden, UT                    1
# n/a            n/a       Cincinnati, OH               1

# %%
pd.pivot_table(data[data.Title == 'Data Scientist'], index=['Title','Location'], values='avg_salary').sort_values('avg_salary', ascending=False)
# Out:
#                                    avg_salary
# Title          Location
# Data Scientist Chevy Chase, MD          139.0
#                Lorton, VA               120.0
#                Boston, MA               114.0
#                Middleton, WI             80.0
#                Laurel, MD                79.0
#                Salt Lake City, UT        79.0
#                Bethany, CT               75.0
#                Alexandria, MN            68.0
#                Dayton, OH                56.0
#                East Syracuse, NY         51.0
#                Winchester, KY            39.0
#                Billerica, MA             35.0
#                White Plains, NY          24.0
#                Baton Rouge, LA           17.0

# %%
data
# Out:
#              Title  Rating                                    Job Description  \
# 0   Data Scientist     3.7  The Data Scientist has a deep understanding of...
# 1   Data Scientist     3.5  Working out of our Chevy Chase, MD/Washington ...
# 2   Data Scientist     3.5  Position Summary:\nThe Senior Scientist is a m...
# 3   Data Scientist     3.5  Alteryx is searching for a Staff Data Scientis...
# 4   Data Scientist     2.5  Who Are We?\nQinetiQ Inc. is a leading innovat...
# 5   Data Scientist     3.4  Classification:\nSalary\nJob Description:\nAre...
# 6   Data Scientist     3.1  The Research department is seeking a qualified...
# 7   Data Scientist     3.5  LGC, Biosearch Technologies is seeking a detai...
# 8   Data Scientist     3.5  LGC, Biosearch Technologies is looking for a h...
# 9   Data Scientist     3.8  White Plains Hospital Job Description\nTitle: ...
# 10   Data Engineer     3.8  Schedule: Mon- Fri Overview:\nThe data enginee...
# 11  Data Scientist     4.7  Are you passionate about using data visualizat...
# 12  Data Scientist     3.5  Position Overview:\nCatalent hires people with...
# 13             n/a    -1.0                                                 -1
# 14  Data Scientist     3.6  Sanvita Medical, an exciting new medical devic...
# 15   Data Engineer     4.5  Overview:\nDo you enjoy working with other peo...
# 16  Data Scientist     3.8  BioFire Diagnostics, LLC. is seeking a bright ...
# 17  Data Scientist     3.8  BioFire Diagnostics (BFDX), LLC. is looking fo...
# 18  Data Scientist     2.0  MedLogic Laboratory\nMolecular Technologist\nL...
# 19   Data Engineer     3.3  The NFI Data and Analytics group is looking fo...
# 20             n/a     4.6  WHO WE LOOK FOR\n\nAn SEI Consultant is a mast...
# 21  Data Scientist     3.5  Position Overview:\nCatalent hires people with...
#
#                                       Company Name            Location  \
# 0                                   Premier Health          Dayton, OH
# 1                                            GEICO     Chevy Chase, MD
# 2                                      LGC Limited      Alexandria, MN
# 3                                    Alteryx, Inc.          Boston, MA
# 4                                     QinetiQ Inc.          Lorton, VA
# 5                          Laticrete International         Bethany, CT
# 6                                    INFICON, Inc.   East Syracuse, NY
# 7                                      LGC Limited       Middleton, WI
# 8                                      LGC Limited       Middleton, WI
# 9                            White Plains Hospital    White Plains, NY
# 10                      America First Credit Union           Ogden, UT
# 11  Johns Hopkins Applied Physics Laboratory (APL)          Laurel, MD
# 12                       Catalent Pharma Solutions      Winchester, KY
# 13                                              -1                  -1
# 14                                 Nova Biomedical       Billerica, MA
# 15                      Idaho Central Credit Union        Chubbuck, ID
# 16                       BioFire Diagnostics, LLC.  Salt Lake City, UT
# 17                       BioFire Diagnostics, LLC.  Salt Lake City, UT
# 18                           MedLogic Laboratories     Baton Rouge, LA
# 19                                  NFI Industries          Camden, NJ
# 20                                             SEI      Cincinnati, OH
# 21                       Catalent Pharma Solutions      Winchester, KY
#
#     Employee Provided  Python  Excel  AWS  SQL Seniority  desc_len  \
# 0                   0       0      0    0    0       n/a       438
# 1                   0       0      0    0    0    Senior       972
# 2                   0       0      0    0    0    Senior       975
# 3                   0       0      0    0    0       n/a      1243
# 4                   0       0      0    0    0       n/a      1084
# 5                   0       0      0    0    0    Senior       549
# 6                   0       0      0    0    0       n/a       944
# 7                   0       0      0    0    0       n/a       717
# 8                   0       0      0    0    0    Senior       938
# 9                   0       0      0    0    0       n/a       479
# 10                  0       0      0    0    0       n/a       898
# 11                  0       0      0    0    0       n/a      2386
# 12                  0       0      0    0    0       n/a      1440
# 13                  0       0      0    0    0       n/a         2
# 14                  0       0      0    0    0       n/a       762
# 15                  0       0      0    0    0       n/a       808
# 16                  0       0      0    0    0       n/a       842
# 17                  0       0      1    0    0       n/a      1169
# 18                  0       0      0    0    0       n/a       488
# 19                  0       1      1    0    1       n/a      3503
# 20                  0       0      1    0    0       n/a      2342
# 21                  0       0      0    0    0       n/a      1431
#
#     min_salary  max_salary  avg_salary  hourly
# 0           56          56        56.0       0
# 1          139         139       139.0       0
# 2           68          68        68.0       0
# 3          114         114       114.0       0
# 4          120         120       120.0       0
# 5           75          75        75.0       0
# 6           51          51        51.0       0
# 7           62          62        62.0       0
# 8           98          98        98.0       0
# 9           48          48        24.0       1
# 10          44          44        44.0       0
# 11          79          79        79.0       0
# 12          38          38        38.0       0
# 13          61          61        61.0       0
# 14          35          35        35.0       0
# 15          61          61        61.0       0
# 16          91          91        91.0       0
# 17          67          67        67.0       0
# 18          34          34        17.0       1
# 19          76          76        76.0       0
# 20          81          81        81.0       0
# 21          40          40        40.0       0

# %%
for i in data[['Rating', 'avg_salary']]:
    df = data[i].value_counts()
    xlabel = sns.barplot(x=df.index, y=df)
    xlabel.set_xticklabels(xlabel.get_xticklabels(),rotation=40)
    plt.show()

# %%
df_pivots = pd.pivot_table(data, index=['Rating'], values='avg_salary')
df_pivots
# Out:
#         avg_salary
# Rating
# -1.0     61.000000
#  2.0     17.000000
#  2.5    120.000000
#  3.1     51.000000
#  3.3     76.000000
#  3.4     75.000000
#  3.5     79.857143
#  3.6     35.000000
#  3.7     56.000000
#  3.8     56.500000
#  4.5     61.000000
#  4.6     81.000000
#  4.7     79.000000

# %%
datax = data[['Title','Job Description', 'Rating','Company Name','Location','Employee Provided','Python','Excel','AWS','SQL','Seniority','desc_len','hourly','avg_salary']]

# pd.pivot_table(data, index=data, values='avg_salary')    

for i in datax.columns:
    if i == 'avg_salary':
        pass
    else:
        print(i, '\n')
        print(pd.pivot_table(datax, index=i, values='avg_salary'))
        print('\n')
        
    
#     pd.pivot_table(data, index=i, values='avg_salary')
#     pivot
# Out:
# Title
#
#                 avg_salary
# Title
# Data Engineer    60.333333
# Data Scientist   69.058824
# n/a              71.000000
#
#
# Job Description
#
#                                                     avg_salary
# Job Description
# -1                                                        61.0
# Alteryx is searching for a Staff Data Scientist...       114.0
# Are you passionate about using data visualizati...        79.0
# BioFire Diagnostics (BFDX), LLC. is looking for...        67.0
# BioFire Diagnostics, LLC. is seeking a bright a...        91.0
# Classification:\nSalary\nJob Description:\nAre ...        75.0
# LGC, Biosearch Technologies is looking for a hi...        98.0
# LGC, Biosearch Technologies is seeking a detail...        62.0
# MedLogic Laboratory\nMolecular Technologist\nLo...        17.0
# Overview:\nDo you enjoy working with other peop...        61.0
# Position Overview:\nCatalent hires people with ...        40.0
# Position Overview:\nCatalent hires people with ...        38.0
# Position Summary:\nThe Senior Scientist is a mu...        68.0
# Sanvita Medical, an exciting new medical device...        35.0
# Schedule: Mon- Fri Overview:\nThe data engineer...        44.0
# The Data Scientist has a deep understanding of ...        56.0
# The NFI Data and Analytics group is looking for...        76.0
# The Research department is seeking a qualified ...        51.0
# WHO WE LOOK FOR\n\nAn SEI Consultant is a maste...        81.0
# White Plains Hospital Job Description\nTitle: C...        24.0
# Who Are We?\nQinetiQ Inc. is a leading innovato...       120.0
# Working out of our Chevy Chase, MD/Washington D...       139.0
#
#
# Rating
#
#         avg_salary
# Rating
# -1.0     61.000000
#  2.0     17.000000
#  2.5    120.000000
#  3.1     51.000000
#  3.3     76.000000
#  3.4     75.000000
#  3.5     79.857143
#  3.6     35.000000
#  3.7     56.000000
#  3.8     56.500000
#  4.5     61.000000
#  4.6     81.000000
#  4.7     79.000000
#
#
# Company Name
#
#                                                 avg_salary
# Company Name
# -1                                                    61.0
# Alteryx, Inc.                                        114.0
# America First Credit Union                            44.0
# BioFire Diagnostics, LLC.                             79.0
# Catalent Pharma Solutions                             39.0
# GEICO                                                139.0
# INFICON, Inc.                                         51.0
# Idaho Central Credit Union                            61.0
# Johns Hopkins Applied Physics Laboratory (APL)        79.0
# LGC Limited                                           76.0
# Laticrete International                               75.0
# MedLogic Laboratories                                 17.0
# NFI Industries                                        76.0
# Nova Biomedical                                       35.0
# Premier Health                                        56.0
# QinetiQ Inc.                                         120.0
# SEI                                                   81.0
# White Plains Hospital                                 24.0
#
#
# Location
#
#                     avg_salary
# Location
# -1                        61.0
# Alexandria, MN            68.0
# Baton Rouge, LA           17.0
# Bethany, CT               75.0
# Billerica, MA             35.0
# Boston, MA               114.0
# Camden, NJ                76.0
# Chevy Chase, MD          139.0
# Chubbuck, ID              61.0
# Cincinnati, OH            81.0
# Dayton, OH                56.0
# East Syracuse, NY         51.0
# Laurel, MD                79.0
# Lorton, VA               120.0
# Middleton, WI             80.0
# Ogden, UT                 44.0
# Salt Lake City, UT        79.0
# White Plains, NY          24.0
# Winchester, KY            39.0
#
#
# Employee Provided
#
#                    avg_salary
# Employee Provided
# 0                   68.045455
#
#
# Python
#
#         avg_salary
# Python
# 0        67.666667
# 1        76.000000
#
#
# Excel
#
#        avg_salary
# Excel
# 0       67.000000
# 1       74.666667
#
#
# AWS
#
#      avg_salary
# AWS
# 0     68.045455
#
#
# SQL
#
#      avg_salary
# SQL
# 0     67.666667
# 1     76.000000
#
#
# Seniority
#
#            avg_salary
# Seniority
# Senior      95.000000
# n/a         62.055556
#
#
# desc_len
#
#           avg_salary
# desc_len
# 2               61.0
# 438             56.0
# 479             24.0
# 488             17.0
# 549             75.0
# 717             62.0
# 762             35.0
# 808             61.0
# 842             91.0
# 898             44.0
# 938             98.0
# 944             51.0
# 972            139.0
# 975             68.0
# 1084           120.0
# 1169            67.0
# 1243           114.0
# 1431            40.0
# 1440            38.0
# 2342            81.0
# 2386            79.0
# 3503            76.0
#
#
# hourly
#
#         avg_salary
# hourly
# 0             72.8
# 1             20.5

# %%
pd.pivot_table(data,index='Location',columns='Python', values='avg_salary',aggfunc='count')
# Out:
# Python                0    1
# Location
# -1                  1.0  NaN
# Alexandria, MN      1.0  NaN
# Baton Rouge, LA     1.0  NaN
# Bethany, CT         1.0  NaN
# Billerica, MA       1.0  NaN
# Boston, MA          1.0  NaN
# Camden, NJ          NaN  1.0
# Chevy Chase, MD     1.0  NaN
# Chubbuck, ID        1.0  NaN
# Cincinnati, OH      1.0  NaN
# Dayton, OH          1.0  NaN
# East Syracuse, NY   1.0  NaN
# Laurel, MD          1.0  NaN
# Lorton, VA          1.0  NaN
# Middleton, WI       2.0  NaN
# Ogden, UT           1.0  NaN
# Salt Lake City, UT  2.0  NaN
# White Plains, NY    1.0  NaN
# Winchester, KY      2.0  NaN

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
data.columns
# Out:
# Index(['Title', 'Rating', 'Job Description', 'Company Name', 'Location',
#        'Employee Provided', 'Python', 'Excel', 'AWS', 'SQL', 'Seniority',
#        'desc_len', 'min_salary', 'max_salary', 'avg_salary', 'hourly'],
#       dtype='object')

# %%
words = " ".join(data['Job Description'])

def punctuation_stop(text):
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered

words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])
wc = WordCloud(background_color = "white", random_state =1 ,stopwords= STOPWORDS, max_words = 2000, width=800, height=800)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
data.to_csv('eda_data.csv')
