# %%
import pandas as pd

# %%
data = pd.read_csv('Glassdoor_jobs.csv')
data
# Out:
#     Unnamed: 0                           Job Title  \
# 0            0           DATA SCIENTIST-HEALTHCARE
# 1            1                Staff Data Scientist
# 2            2                       R&D Scientist
# 3            3  Business Intelligence Data Analyst
# 4            4                      Data Scientist
# 5            5                                  -1
# 6            6                                  -1
# 7            7              Workforce Data Analyst
# 8            8     Research Scientist I - Essentia
# 9            9                 Associate Scientist
# 10          10                Staff Data Scientist
# 11          11                      Data Scientist
# 12          12                      Data Scientist
# 13          13                Senior R&D Scientist
# 14          14                                  -1
#
#                    Salary Estimate  \
# 0                               -1
# 1                               -1
# ...
