# %%
import pandas as pd

# %%
data = pd.read_csv('Glassdoor_jobs.csv')
data

data['Per Hour'] = data['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
data['Employee Provided'] = data['Salary Estimate'].apply(lambda x: 1 if 'employee provided salary' in x.lower() else 0)

# %% [markdown]
# # Data cleaning
# 1. Remove Employer Provided Salary
# 2. In job description, just add the requrements like (Python & so on)
# 3. Remove null values

# %%
data = data[data['Salary Estimate'] != '-1']
salary = data['Salary Estimate'].apply(lambda x: x.split('(')[0])
salary = salary.apply(lambda x: x.replace('Per Hour','').replace('$','').replace('K',''))
salary
# Out:
# 1       56 - 96
# 2     139 - 214
# 4       68 - 97
# 5     114 - 144
# 6     120 - 121
# 8      75 - 146
# 11     51 - 107
# 12      62 - 73
# 14     98 - 121
# 15      24 - 39
# 16      44 - 87
# 17     79 - 136
# 18      38 - 67
# 19      61 - 84
# 20      35 - 72
# 21      61 - 69
# 22      91 - 97
# 23      67 - 68
# 26      17 - 23
# 27     76 - 133
# 28     81 - 123
# 29      40 - 71
# Name: Salary Estimate, dtype: object

# %%
data['Min Salary'] = salary.apply(lambda x : int(x.split('-')[0]))
data['Max Salary'] = salary.apply(lambda x : int(x.split('-')[0]))
data['Average Salary'] = (data['Min Salary']+ data['Max Salary'])/2
data
# Out:
#                                             Job Title  \
# 1                           DATA SCIENTIST-HEALTHCARE
# 2                            Principal Data Scientist
# 4                                    Senior Scientist
# 5                                Staff Data Scientist
# 6                                      Data Scientist
# 8                                    Senior Scientist
# 11                                   Plasma Scientist
# 12                                      R&D Scientist
# 14                               Senior R&D Scientist
# 15                      CLINICAL LABORATORY SCIENTIST
# 16                                      Data Engineer
# 17                       Data Visualization Scientist
# 18                     Associate Analytical Scientist
# 19                                                 -1
# 20                                Associate Scientist
# 21                                      Data Engineer
# 22                   Associate Data Scientist I or II
# 23                                  Scientist I or II
# 26  Medical Laboratory Scientist/Medical Technologist
# 27                                      Data Engineer
# 28                        Data & Analytics Consultant
# 29                               Analytical Scientist
#
#                        Salary Estimate  \
# 1         $56K - $96K (Glassdoor est.)
# 2       $139K - $214K (Glassdoor est.)
# 4         $68K - $97K (Glassdoor est.)
# 5       $114K - $144K (Glassdoor est.)
# 6       $120K - $121K (Glassdoor est.)
# 8        $75K - $146K (Glassdoor est.)
# 11       $51K - $107K (Glassdoor est.)
# 12        $62K - $73K (Glassdoor est.)
# 14       $98K - $121K (Glassdoor est.)
# 15  $24 - $39 Per Hour(Glassdoor est.)
# 16        $44K - $87K (Glassdoor est.)
# 17       $79K - $136K (Glassdoor est.)
# 18        $38K - $67K (Glassdoor est.)
# 19        $61K - $84K (Glassdoor est.)
# 20        $35K - $72K (Glassdoor est.)
# 21        $61K - $69K (Glassdoor est.)
# 22        $91K - $97K (Glassdoor est.)
# 23        $67K - $68K (Glassdoor est.)
# 26  $17 - $23 Per Hour(Glassdoor est.)
# 27       $76K - $133K (Glassdoor est.)
# 28       $81K - $123K (Glassdoor est.)
# 29        $40K - $71K (Glassdoor est.)
#
#                                       Job Description  Rating  \
# 1   The Data Scientist has a deep understanding of...     3.7
# 2   Working out of our Chevy Chase, MD/Washington ...     3.5
# 4   Position Summary:\nThe Senior Scientist is a m...     3.5
# 5   Alteryx is searching for a Staff Data Scientis...     3.5
# 6   Who Are We?\nQinetiQ Inc. is a leading innovat...     2.5
# 8   Classification:\nSalary\nJob Description:\nAre...     3.4
# 11  The Research department is seeking a qualified...     3.1
# 12  LGC, Biosearch Technologies is seeking a detai...     3.5
# 14  LGC, Biosearch Technologies is looking for a h...     3.5
# 15  White Plains Hospital Job Description\nTitle: ...     3.8
# 16  Schedule: Mon- Fri Overview:\nThe data enginee...     3.8
# 17  Are you passionate about using data visualizat...     4.7
# 18  Position Overview:\nCatalent hires people with...     3.5
# 19                                                 -1    -1.0
# 20  Sanvita Medical, an exciting new medical devic...     3.6
# 21  Overview:\nDo you enjoy working with other peo...     4.5
# 22  BioFire Diagnostics, LLC. is seeking a bright ...     3.8
# 23  BioFire Diagnostics (BFDX), LLC. is looking fo...     3.8
# 26  MedLogic Laboratory\nMolecular Technologist\nL...     2.0
# 27  The NFI Data and Analytics group is looking fo...     3.3
# 28  WHO WE LOOK FOR\n\nAn SEI Consultant is a mast...     4.6
# 29  Position Overview:\nCatalent hires people with...     3.5
#
#                                       Company Name            Location  \
# 1                                   Premier Health          Dayton, OH
# 2                                            GEICO     Chevy Chase, MD
# 4                                      LGC Limited      Alexandria, MN
# 5                                    Alteryx, Inc.          Boston, MA
# 6                                     QinetiQ Inc.          Lorton, VA
# 8                          Laticrete International         Bethany, CT
# 11                                   INFICON, Inc.   East Syracuse, NY
# 12                                     LGC Limited       Middleton, WI
# 14                                     LGC Limited       Middleton, WI
# 15                           White Plains Hospital    White Plains, NY
# 16                      America First Credit Union           Ogden, UT
# 17  Johns Hopkins Applied Physics Laboratory (APL)          Laurel, MD
# 18                       Catalent Pharma Solutions      Winchester, KY
# 19                                              -1                  -1
# 20                                 Nova Biomedical       Billerica, MA
# 21                      Idaho Central Credit Union        Chubbuck, ID
# 22                       BioFire Diagnostics, LLC.  Salt Lake City, UT
# 23                       BioFire Diagnostics, LLC.  Salt Lake City, UT
# 26                           MedLogic Laboratories     Baton Rouge, LA
# 27                                  NFI Industries          Camden, NJ
# 28                                             SEI      Cincinnati, OH
# 29                       Catalent Pharma Solutions      Winchester, KY
#
#     Per Hour  Employee Provided  Min Salary  Max Salary  Average Salary
# 1          0                  0          56          56            56.0
# 2          0                  0         139         139           139.0
# 4          0                  0          68          68            68.0
# 5          0                  0         114         114           114.0
# 6          0                  0         120         120           120.0
# 8          0                  0          75          75            75.0
# 11         0                  0          51          51            51.0
# 12         0                  0          62          62            62.0
# 14         0                  0          98          98            98.0
# 15         1                  0          24          24            24.0
# 16         0                  0          44          44            44.0
# 17         0                  0          79          79            79.0
# 18         0                  0          38          38            38.0
# 19         0                  0          61          61            61.0
# 20         0                  0          35          35            35.0
# 21         0                  0          61          61            61.0
# 22         0                  0          91          91            91.0
# 23         0                  0          67          67            67.0
# 26         1                  0          17          17            17.0
# 27         0                  0          76          76            76.0
# 28         0                  0          81          81            81.0
# 29         0                  0          40          40            40.0

# %%
data['Python'] = data['Job Description'].apply(lambda x: 1 if 'Python' in x else 0 )
data.Python.value_counts()
# Out:
# 0    21
# 1     1
# Name: Python, dtype: int64

# %%
data['R_studio'] = data['Job Description'].apply(lambda x: 1 if 'r-studio' or 'r studio' in x.lower() else 0 )
data.R_studio.value_counts()
# Out:
# 1    22
# Name: R_studio, dtype: int64

# %%
data['Spark'] = data['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0 )
data.Spark.value_counts()
# Out:
# 0    22
# Name: Spark, dtype: int64

# %%
data['Excel'] = data['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0 )
data.Excel.value_counts()
# Out:
# 0    19
# 1     3
# Name: Excel, dtype: int64

# %%
data['AWS'] = data['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0 )
data.AWS.value_counts()
# Out:
# 0    22
# Name: AWS, dtype: int64

# %%
data['SQL'] = data['Job Description'].apply(lambda x: 1 if 'sql' in x.lower() else 0 )
data.SQL.value_counts()
# Out:
# 0    21
# 1     1
# Name: SQL, dtype: int64

# %%
data.to_csv('Cleaned_Data.csv', index=False)
